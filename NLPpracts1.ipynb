# %% [markdown]
# <a href="https://colab.research.google.com/github/ron-980/projectZero/blob/master/NLPpracts1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Word Tokenize**

# %%
# !pip install nltk
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
text = "I love AI. NLP is intresting. Python is easy."

# %%
sentences = sent_tokenize(text)

# %%
print(sentences)
# Out:
# ['I love AI.', 'NLP is intresting.', 'Python is easy.']

# %% [markdown]
# **Stop Word Removal**

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
text = "This is an example of Natural Language Processing"
words = word_tokenize(text)

filtered = []

for word in words:
  if word.lower() not in stop_words:
    filtered.append(word)

print(filtered)
# Out:
# ['example', 'Natural', 'Language', 'Processing']

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()
words = ["playing", "plays", "better", "studies", "flying", "dries", "runs",
         "goodies"]
for word in words:
  stemmed = stemmer.stem(word)
  print(word, "-->", stemmed)
# Out:
# playing --> play
# plays --> play
# better --> better
# studies --> studi
# flying --> fli
# dries --> dri
# runs --> run
# goodies --> goodi

# %% [markdown]
# **Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
lemmatizer = WordNetLemmatizer()

words = ["playing", "plays", "better", "studies", "flying", "dries", "runs",
         "goodies", "flies", "dies", "children"]
for word in words:
  print(word, "-->", lemmatizer.lemmatize(word))
# Out:
# playing --> playing
# plays --> play
# better --> better
# studies --> study
# flying --> flying
# dries --> dry
# runs --> run
# goodies --> goody
# flies --> fly
# dies --> dy
# children --> child
